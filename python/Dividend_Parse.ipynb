# %%
import pandas as pd

# %%
df = pd.read_excel("U.S.DividendChampions.xls", sheetname = "Champions", header=5)
df = df.sort_values(by=["Yield",'Dividend'], ascending=[False,False])
df.iloc[:,:25]
# Out:
#                               Name Symbol                 Industry   Yrs  \
# 49          Helmerich & Payne Inc.     HP                  Oil&Gas  44.0
# 9                        AT&T Inc.      T       Telecommunications  33.0
# 69      National Retail Properties    NNN              REIT-Retail  27.0
# 63           Mercury General Corp.    MCY                Insurance  30.0
# 91                    Target Corp.    TGT          Retail-Discount  49.0
# 21                   Chevron Corp.    CVX                  Oil&Gas  29.0
# 76       People's United Financial   PBCT                  Banking  25.0
# 73      Old Republic International    ORI                Insurance  36.0
# 39                ExxonMobil Corp.    XOM                  Oil&Gas  35.0
# 100  Universal Health Realty Trust    UHT         REIT-Health Care  30.0
# 98          United Bankshares Inc.   UBSI                  Banking  43.0
# 31             Consolidated Edison     ED         Utility-Electric  43.0
# ...

# %%
df['Dividend']
# Out:
# 0      0.76000
# 1      4.70000
# 2      0.68000
# 3      1.72000
# 4      3.80000
# 5      2.44000
# 6      0.96800
# 7      0.76520
# 8      1.28000
# 9      1.96000
# 10     1.80000
# 11     2.28000
# 12     2.92000
# 13     1.20000
# 14     1.78000
# 15     0.82000
# 16     0.73000
# 17     1.04000
# 18     0.72000
# 19     1.40000
# 20     0.50000
# 21     4.32000
# 22     2.00000
# 23     1.33000
# 24     3.36000
# 25     1.48000
# 26     1.60000
# 27     0.90000
# 28     1.28000
# 29     1.12000
#         ...
# 80     0.84000
# 81     1.20000
# 82     1.64000
# 83     0.56000
# 84     3.40000
# 85     0.87000
# 86     1.56000
# 87     2.32000
# 88     0.82000
# 89     1.32000
# 90     2.28000
# 91     2.40000
# 92     0.62000
# 93     0.84000
# 94     1.80000
# 95     0.36000
# 96     1.00000
# 97     1.02000
# 98     1.32000
# 99     2.16000
# 100    2.62000
# 101    1.68000
# 102    1.68000
# 103    5.12000
# 104    1.50000
# 105    2.04000
# 106    1.56000
# 107    0.88000
# ...

# %%
df.columns
# Out:
# Index([     'Name',    'Symbol',  'Industry',       'Yrs',       'Seq',
#               'DR',        'SP',     'Price',     'Yield',       'Old',
#              'New',      'Inc.',    'Ex-Div',    'Record',       'Pay',
#              'Sch',      'Note',  'Dividend',    'Payout',    'Graham',
#              'P/E',     'Month',       'EPS',     'Ratio',   'P/Sales',
#           'P/Book',       'ROE',    'Growth',  'Growth.1',  'Growth.2',
#         'Growth.3',         'A',    '($Mil)',      'Own.',    'Equity',
#              'DEG',      'A/D*',      '1-yr',      '3-yr',      '5-yr',
#            '10-yr',        2016,        2015,        2014,        2013,
#                '#',        2012,        2011,       '#.1',        2010,
#               2009,        2008,        2007,        2006,        2005,
#               2004,        2003,        2002,        2001,        2000,
#               1999,   'RegDivs',    '2015.1',    '2014.1',    '2013.1',
# ...
